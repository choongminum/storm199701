# %%
from datetime import timedelta
import ggcmpy
from ggcmpy.timeseries import read_ggcm_solarwind_directory, store_to_pyspedas
import matplotlib.pyplot as plt
from matplotlib import colors
import pandas as pd
import numpy as np
import pathlib
import pyspedas
from pyspedas import options, tplot, get_data, store_data, tplot_names
import xarray as xr

# %%
trange = ["1997-01-10/00:00:00", "1997-01-10/14:00:00"]

# Download OMNI data.
pyspedas.omni.data(trange=trange, datatype="1min", time_clip=True)
# Out:
# 13-Mar-26 04:06:08: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/omni/omni_cdaweb/hro_1min/1997/
# 13-Mar-26 04:06:09: File is current: omni_data/hro_1min/1997/omni_hro_1min_19970101_v01.cdf
# ['IMF',
#  'PLS',
#  'IMF_PTS',
#  'PLS_PTS',
#  'percent_interp',
#  'Timeshift',
#  'RMS_Timeshift',
#  'RMS_phase',
#  'Time_btwn_obs',
#  'F',
#  'BX_GSE',
#  'BY_GSE',
#  'BZ_GSE',
#  'BY_GSM',
#  'BZ_GSM',
#  'RMS_SD_B',
#  'RMS_SD_fld_vec',
#  'flow_speed',
#  'Vx',
#  'Vy',
#  'Vz',
#  'proton_density',
#  'T',
#  'Pressure',
#  'E',
#  'Beta',
#  'Mach_num',
#  'Mgs_mach_num',
#  'x',
#  'y',
#  'z',
#  'BSN_x',
#  'BSN_y',
#  'BSN_z',
#  'AE_INDEX',
#  'AL_INDEX',
#  'AU_INDEX',
#  'SYM_D',
#  'SYM_H',
#  'ASY_D',
#  'ASY_H',
#  'PC_N_INDEX']

# %%
# Set the plotting style.
plt.style.use("seaborn-v0_8-whitegrid")

# %%
# Plot the SYM-H index.
options("SYM_H", "ytitle", "SYM-H (nT)")

vars_to_plot = ["SYM_H"]

options(vars_to_plot, "alpha", 1.0)
options(vars_to_plot, "line_width", 0.75)

# Plot the geomagnetic data.
tplot(vars_to_plot, trange, ysize=2.5 * len(vars_to_plot))

# %%
# Extract data.
time_sym_h, data_sym_h = get_data("SYM_H")

# Create a DataFrame.
df = pd.DataFrame({"Time": time_sym_h, "SYM-H": data_sym_h})

# Set index to datetime for easier slicing.
df["Time"] = pd.to_datetime(df["Time"], unit="s")
df.set_index("Time", inplace=True)

# %%
# Classify storms into four categories.
def classify_storm(min_sym_h):
    if min_sym_h <= -250:
        return "Super"
    elif min_sym_h <= -100:
        return "Large"
    elif min_sym_h <= -50:
        return "Moderate"
    elif min_sym_h <= -30:
        return "Small"
    else:
        return "Quiet"


storms = []
threshold = -30
window_hours = 48  # Group events within 48 hours as one storm.

active_periods = df[df["SYM-H"] <= threshold]

if not active_periods.empty:
    # Group active times into discrete events.
    gaps = active_periods.index.to_series().diff() > timedelta(
        hours=window_hours
    )
    event_ids = gaps.cumsum()

    for _, group in active_periods.groupby(event_ids):
        # Define the event window.
        start = group.index.min()
        end = group.index.max()

        # Grab a slightly larger slice to ensure we see the full picture.
        storm_slice = df[
            start - timedelta(hours=12) : end + timedelta(hours=12)
        ]

        # Calculate the minimum.
        min_sym_h_val = storm_slice["SYM-H"].min()
        min_sym_h_time = storm_slice["SYM-H"].idxmin()

        storms.append(
            {
                "Classification": classify_storm(min_sym_h_val),
                "Min SYM-H (nT)": min_sym_h_val,
                "Min SYM-H Time (UT)": min_sym_h_time,
            }
        )

# %%
# Display the result in a table.
results = pd.DataFrame(storms)
print(f"The number of storms identified: {len(results)}")
display(results)
# Out:
# The number of storms identified: 1
#   Classification  Min SYM-H (nT) Min SYM-H Time (UT)
# 0       Moderate             -85 1997-01-10 09:21:00

# %%
# Check each storm for Sudden Storm Commencements.
for i, row in results.iterrows():
    peak_time = row["Min SYM-H Time (UT)"]
    classification = row["Classification"]

    # Define search window: 48 hours before the peak
    start_search = peak_time - timedelta(hours=48)
    end_search = peak_time

    window_df = df[start_search:end_search].copy()
    window_df["Delta_SYM-H"] = window_df["SYM-H"].diff()

    # Check for SSC Condition: An increase of >= 20 nT SYM-H in one hour
    ssc_candidates = window_df[window_df["Delta_SYM-H"] >= 20]

    print(f"\nStorm {i}: {classification}")
    print(f"  - Peak time: {peak_time}")
    print(f"  - Peak SYM-H: {row['Min SYM-H (nT)']} nT")

    if not ssc_candidates.empty:
        print(f"  - Potential SSC(s) found:")
        for t, jump in zip(
            ssc_candidates.index, ssc_candidates["Delta_SYM-H"]
        ):
            print(f"    * {t}: +{jump:.1f} nT jump")
    else:
        print("  - No SSC (> 20 nT jump within an hour) detected.")
# Out:
# Storm 0: Moderate
#   - Peak time: 1997-01-10 09:21:00
#   - Peak SYM-H: -85 nT
#   - No SSC (> 20 nT jump within an hour) detected.

# %%
# Add OpenGGCM data.
RUN_NAME = "c030"
RUN_DIR = pathlib.Path("/mnt/home/germaschewski/cu1010/runs/raeder") / RUN_NAME
SW_DIR = pathlib.Path(
    "/mnt/home/germaschewski/cu1010/runs/251118_1330_c034_AZ/inp"
)
DATA_DIR = RUN_DIR

# %%
# OpenGGCM input data
wi = read_ggcm_solarwind_directory(SW_DIR, glob="wi.*")
store_to_pyspedas(wi)

# %%
# OpenGGCM ionosphere output
iono_files = sorted(DATA_DIR.glob(f"{RUN_NAME}.iof.*"))
iof = xr.open_mfdataset(iono_files)
# Out:
# 13-Mar-26 04:06:47: /tmp/ipykernel_2197458/3391077074.py:3: FutureWarning: In a future version of xarray the default value for data_vars will change from data_vars='all' to data_vars=None. This is likely to lead to different results when multiple datasets have matching variables with overlapping values. To opt in to new defaults and get rid of these warnings now use `set_options(use_new_combine_kwarg_defaults=True) or set data_vars explicitly.
#   iof = xr.open_mfdataset(iono_files)

# %%
# Calculate ground magnetic perturbations and put into a DataArray.
delbp = [
    ggcmpy.iono.iopar(iof.isel(time=i)).delbp for i in range(len(iof.time))
]
iof["delbp"] = xr.concat(delbp, dim="time")
delbt = [
    ggcmpy.iono.iopar(iof.isel(time=i)).delbt for i in range(len(iof.time))
]
iof["delbt"] = xr.concat(delbt, dim="time")

# %%
# Calculate the AL index.
ggcm_al = iof.ggcm.al_index()
ggcmpy.timeseries.store_to_pyspedas(ggcm_al["ggcm.al"])
pyspedas.store_data("al", data=["AL_INDEX", "ggcm.al"])
# Out:
# True

# %%
# Calculate |dB/dt|.
delbh_t = iof.ggcm.delbhdelt()

# %%
# Calculate the maximum along lats and longs dimensions.
delbh_t_max = delbh_t.max(dim=["lats", "longs"])
delbh_t_max.attrs["units"] = "nT/s"
delbh_t_max.name = "delbh_t_max"
store_to_pyspedas(delbh_t_max)

# %%
# Calculate the cross-polar-cap-potential.
cpcp = iof.ggcm.cpcp() * 1e-3
cpcp.attrs["long_name"] = "CPCP"
cpcp.attrs["units"] = "kV"
store_to_pyspedas(cpcp)

# %%
# Calculate Joule heating.
xjh = [ggcmpy.iono.iopar(iof.isel(time=i)).xjh for i in range(len(iof.time))]
iof["xjh"] = xr.concat(xjh, dim="time")
jh = iof.ggcm.jh() * 1e-9
jh.attrs["units"] = "GW"
store_to_pyspedas(jh)

# %%
# Set plotting options.

# IMF Bz
options("BZ_GSE", "yrange", [-20, 20])
options("BZ_GSE", "ytitle", "IMF Bz")

# Solar Wind Speed
options("flow_speed", "ytitle", "Speed")

# Solar Wind Density
options("proton_density", "ylog", True)
options("proton_density", "yrange", [1, 100])
options("proton_density", "ytitle", "Density")

# Flow Pressure (Dynamic Pressure)
options("Pressure", "ytitle", "Dyn. Pressure")

# AE Index
options("AE_INDEX", "ytitle", "AE Index")

# AL Index
options("al", "yrange", [-2000, 0])
options("al", "ytitle", "AL Index")
options("al", "color", ["black", "red"])
options("al", "legend_names", ["OMNI", "OpenGGCM"])
options("al", "legend_location", "lower right")

# CPCP
options("cpcp", "yrange", [0, 700])
options("cpcp", "legend_names", "OpenGGCM")
options("cpcp", "legend_location", "upper right")

# Joule heating
options("jh", "ylog", True)
options("jh", "yrange", [1, 10000])
options("jh", "legend_names", "OpenGGCM")
options("jh", "legend_location", "upper right")

# max[|dB/dt|]
options("delbh_t_max", "ytitle", "max[|dB/dt|]")
options("delbh_t_max", "legend_names", "OpenGGCM")
options("delbh_t_max", "legend_location", "lower right")

# %%
vars_to_plot = [
    "BZ_GSE",
    "proton_density",
    # "flow_speed",
    # "SYM_H",
    "al",
    "delbh_t_max",
    "cpcp",
    "jh",
]

options(vars_to_plot, "alpha", 1.0)
options(vars_to_plot, "line_width", 0.75)

# Plot the geomagnetic data.
tplot(vars_to_plot, trange, ysize=2.5 * len(vars_to_plot))

# %%
mag_files = sorted(DATA_DIR.glob(f"{RUN_NAME}.py_0.*"))
py_0 = xr.open_mfdataset(mag_files)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File /mnt/gpfs01/home/germaschewski/cu1010/repos/ggcmpy/src/ggcmpy/jrrle_store.py:238, in JrrleStore.coords(self, shape)
#     237     grid2_filename = pathlib.Path(meta["dirname"] / f"{meta['run']}.grid2")
# --> 238     coords: dict[str, Any] = openggcm.read_grid2(grid2_filename)
#     239 except FileNotFoundError:
#
# File /mnt/gpfs01/home/germaschewski/cu1010/repos/ggcmpy/src/ggcmpy/openggcm.py:71, in read_grid2(filename)
#      69 def read_grid2(filename: os.PathLike[Any] | str) -> dict[str, NDArray[Any]]:
#      70     # load the cell centered grid
# ---> 71     with Path(filename).open(encoding="utf-8") as fin:
#      72         nx = int(next(fin).split()[0])
#
# File ~/miniconda3/envs/0312/lib/python3.12/pathlib.py:1013, in Path.open(self, mode, buffering, encoding, errors, newline)
#    1012     encoding = io.text_encoding(encoding)
# -> 1013 return io.open(self, mode, buffering, encoding, errors, newline)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/mnt/home/germaschewski/cu1010/runs/raeder/c030/c030.grid2'
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[20], line 2
#       1 mag_files = sorted(DATA_DIR.glob(f"{RUN_NAME}.py_0.*"))
# ----> 2 py_0 = xr.open_mfdataset(mag_files)
#
# File ~/miniconda3/envs/0312/lib/python3.12/site-packages/xarray/backends/api.py:1638, in open_mfdataset(paths, chunks, concat_dim, compat, preprocess, engine, data_vars, coords, combine, parallel, join, attrs_file, combine_attrs, errors, **kwargs)
#    1636 for p in paths1d:
#    1637     try:
# -> 1638         ds = open_(p, **open_kwargs)
#    1639         datasets.append(ds)
#    1640     except Exception as e:
#
# File ~/miniconda3/envs/0312/lib/python3.12/site-packages/xarray/backends/api.py:607, in open_dataset(filename_or_obj, engine, chunks, cache, decode_cf, mask_and_scale, decode_times, decode_timedelta, use_cftime, concat_characters, decode_coords, drop_variables, create_default_indexes, inline_array, chunked_array_type, from_array_kwargs, backend_kwargs, **kwargs)
#     595 decoders = _resolve_decoders_kwargs(
#     596     decode_cf,
#     597     open_backend_dataset_parameters=backend.open_dataset_parameters,
#    (...)    603     decode_coords=decode_coords,
#     604 )
#     606 overwrite_encoded_chunks = kwargs.pop("overwrite_encoded_chunks", None)
# --> 607 backend_ds = backend.open_dataset(
#     608     filename_or_obj,
#     609     drop_variables=drop_variables,
#     610     **decoders,
#     611     **kwargs,
#     612 )
#     613 ds = _dataset_from_backend_dataset(
#     614     backend_ds,
#     615     filename_or_obj,
#    (...)    626     **kwargs,
#     627 )
#     628 return ds
#
# File /mnt/gpfs01/home/germaschewski/cu1010/repos/ggcmpy/src/ggcmpy/jrrle_backend.py:58, in JrrleEntrypoint.open_dataset(self, filename_or_obj, mask_and_scale, decode_times, concat_characters, decode_coords, drop_variables, use_cftime, decode_timedelta)
#      54     raise TypeError(msg)
#      56 store_entrypoint = StoreBackendEntrypoint()
# ---> 58 return store_entrypoint.open_dataset(
#      59     store,
#      60     mask_and_scale=mask_and_scale,
#      61     decode_times=decode_times,
#      62     concat_characters=concat_characters,
#      63     decode_coords=decode_coords,
#      64     drop_variables=drop_variables,
#      65     use_cftime=use_cftime,
#      66     decode_timedelta=decode_timedelta,
#      67 )
#
# File ~/miniconda3/envs/0312/lib/python3.12/site-packages/xarray/backends/store.py:42, in StoreBackendEntrypoint.open_dataset(self, filename_or_obj, mask_and_scale, decode_times, concat_characters, decode_coords, drop_variables, set_indexes, use_cftime, decode_timedelta)
#      27 def open_dataset(
#      28     self,
#      29     filename_or_obj: T_PathFileOrDataStore,
#    (...)     38     decode_timedelta=None,
#      39 ) -> Dataset:
#      40     assert isinstance(filename_or_obj, AbstractDataStore)
# ---> 42     vars, attrs = filename_or_obj.load()
#      43     encoding = filename_or_obj.get_encoding()
#      45     vars, attrs, coord_names = conventions.decode_cf_variables(
#      46         vars,
#      47         attrs,
#    (...)     54         decode_timedelta=decode_timedelta,
#      55     )
#
# File ~/miniconda3/envs/0312/lib/python3.12/site-packages/xarray/backends/common.py:366, in AbstractDataStore.load(self)
#     347 def load(self):
#     348     """
#     349     This loads the variables and attributes simultaneously.
#     350     A centralized loading function makes it easier to create
#    (...)    363     are requested, so care should be taken to make sure its fast.
#     364     """
#     365     variables = FrozenDict(
# --> 366         (_decode_variable_name(k), v) for k, v in self.get_variables().items()
#     367     )
#     368     attributes = FrozenDict(self.get_attrs())
#     369     return variables, attributes
#
# File /mnt/gpfs01/home/germaschewski/cu1010/repos/ggcmpy/src/ggcmpy/jrrle_store.py:311, in JrrleStore.get_variables(self)
#     308     variables[fld] = self.open_store_variable(fld, fld_info)
#     310 assert shape is not None
# --> 311 variables.update(self.coords(shape))
#     313 variables["time"] = Variable(("time"), [np.datetime64(time, "ns")])
#     314 variables["inttime"] = Variable(("time"), [inttime])
#
# File /mnt/gpfs01/home/germaschewski/cu1010/repos/ggcmpy/src/ggcmpy/jrrle_store.py:241, in JrrleStore.coords(self, shape)
#     239 except FileNotFoundError:
#     240     grid_filename = pathlib.Path(meta["dirname"] / f"{meta['run']}.grid")
# --> 241     coords = openggcm.read_grid(grid_filename)
#     242 if meta["type"] == "2df":
#     243     coords[meta["plane"]] = [meta["plane_location"]]
#
# File /mnt/gpfs01/home/germaschewski/cu1010/repos/ggcmpy/src/ggcmpy/openggcm.py:61, in read_grid(filename)
#      60 def read_grid(filename: os.PathLike[Any] | str) -> dict[str, NDArray[Any]]:
# ---> 61     with jrrle.JrrleFile(filename) as file:
#      62         return {
#      63             "x": file.read_field("gridx")[1],
#      64             "y": file.read_field("gridy")[1],
#      65             "z": file.read_field("gridz")[1],
#      66         }
#
# File /mnt/gpfs01/home/germaschewski/cu1010/repos/ggcmpy/src/ggcmpy/backends/jrrle/jrrle_file.py:73, in JrrleFile.__init__(self, filename, mode)
#      71 self.fields_seen: OrderedDict[str, Any] = OrderedDict()
#      72 self.seen_all_fields = False
# ---> 73 super().__init__(filename)
#
# File /mnt/gpfs01/home/germaschewski/cu1010/repos/ggcmpy/src/ggcmpy/backends/jrrle/fortran_file.py:32, in FortranFile.__init__(self, name, debug)
#      30 self.filename = os.fspath(name)
#      31 self.debug = debug
# ---> 32 self._open()
#
# File /mnt/gpfs01/home/germaschewski/cu1010/repos/ggcmpy/src/ggcmpy/backends/jrrle/fortran_file.py:47, in FortranFile._open(self)
#      45 if unit < 0:
#      46     msg = f"Fortran open error ({unit}) on '{self.filename}'"
# ---> 47     raise RuntimeError(msg)
#      48 self._unit = unit
#      49 _fortran_units[self._unit] += 1
#
# RuntimeError: Fortran open error (-2) on '/mnt/home/germaschewski/cu1010/runs/raeder/c030/c030.grid'

# %%
# Determine the maximum time step.
time_max = iof.time.shape[0]

# %%
# Density
py_0.rr.sel(x=slice(-50.0, 100.0), z=slice(-50.0, 50.0)).isel(
    time=slice(0, time_max, 40)
).T.plot(col="time", col_wrap=4, aspect=1.5, size=4, norm=colors.LogNorm());

# %%
# Pressure
py_0.pp.sel(x=slice(-50.0, 100.0), z=slice(-50.0, 50.0)).isel(
    time=slice(0, time_max, 40)
).T.plot(col="time", col_wrap=4, aspect=1.5, size=4, norm=colors.LogNorm());

# %%
# Pedersen and Hall conductances
for i in range(1, time_max, 80):
    iof.isel(time=i).sigp.ggcm.plot()

# %%
for i in range(1, time_max, 80):
    iof.isel(time=i).sigh.ggcm.plot()

# %%
# Diffuse and discrete electron precipitation energy flux
for i in range(1, time_max, 80):
    iof.isel(time=i).prec_e_fe_1.ggcm.plot()

# %%
for i in range(1, time_max, 80):
    iof.isel(time=i).prec_e_fe_2.ggcm.plot()

# %%
for i in range(1, time_max, 80):
    iof["delbh_t"].isel(time=i).ggcm.plot()
